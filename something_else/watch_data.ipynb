# %%
import os, sys, pandas
sys.path.append('/home/clb/AQP')

# %%
from utils import *

# %%
df = LoadTable('order')

# %%
df[:10]
# Out:
#    O_ORDERKEY  O_CUSTKEY O_ORDERSTATUS  O_TOTALPRICE O_ORDERDATE  \
# 0           2      78002             O      46929.18  1996-12-01
# 1           3     123314             F     193846.25  1993-10-14
# 2           4     136777             O      32151.78  1995-10-11
# 3           5      44485             F     144659.20  1994-07-30
# 4           6      55624             F      58749.59  1992-02-21
# 5           7      39136             O     252004.18  1996-01-10
# 6          32     130057             O     208660.75  1995-07-16
# 7          33      66958             F     163243.98  1993-10-27
# 8          34      61001             O      58949.67  1998-07-21
# 9          35     127588             O     253724.56  1995-10-23
#
#    O_ORDERPRIORITY          O_CLERK
# 0         1-URGENT  Clerk#000000880
# 1            5-LOW  Clerk#000000955
# 2            5-LOW  Clerk#000000124
# 3            5-LOW  Clerk#000000925
# 4  4-NOT SPECIFIED  Clerk#000000058
# ...

# %%
gb = df.groupby('O_ORDERSTATUS')

# %%
list(gb)
# Out:
# [('F',
#            O_ORDERKEY  O_CUSTKEY O_ORDERSTATUS  O_TOTALPRICE O_ORDERDATE  \
#   1                 3     123314             F     193846.25  1993-10-14
#   3                 5      44485             F     144659.20  1994-07-30
#   4                 6      55624             F      58749.59  1992-02-21
#   7                33      66958             F     163243.98  1993-10-27
#   11               37      86116             F     206680.66  1992-06-03
#   ...             ...        ...           ...           ...         ...
#   1499986     5999940      22351             F      14349.56  1994-08-26
#   1499988     5999942     110807             F      32586.85  1994-05-13
#   1499990     5999968      12896             F     354575.46  1992-12-24
#   1499996     5999974      55448             F      92750.90  1993-07-28
#   1499997     5999975     113398             F      63216.65  1993-07-25
#
#            O_ORDERPRIORITY          O_CLERK
# ...
